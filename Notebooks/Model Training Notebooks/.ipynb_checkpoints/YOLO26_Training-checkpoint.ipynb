# %% [markdown]
# # MDP - YOLO26 Training (Local / Offline)
#
# Trains an [Ultralytics YOLO26](https://docs.ultralytics.com/models/yolo26/) detector on **your own machine** (NVIDIA GPU / CUDA) using the `ultralytics` package. No Google Drive or Colab required.
#
# YOLO26 is trained through the `ultralytics` package (`from ultralytics import YOLO`) - there is no separate training repo to clone. The only network access this workflow needs is a **one-time** download of the pretrained COCO starting checkpoint (`yolo26s.pt`) and the initial `pip install`.

# %% [markdown]
# # Step 1: Install & Verify Environment
#
# Run the following once in a terminal (from the repo root or anywhere):
#
# ```bash
# python -m venv .venv
# source .venv/bin/activate      # Windows: .venv\Scripts\activate
# pip install --upgrade pip
# pip install ultralytics
# ```
#
# If PyTorch is not already CUDA-enabled, install the CUDA build that matches your driver, e.g. for CUDA 12.1:
#
# ```bash
# pip install torch torchvision --index-url https://download.pytorch.org/whl/cu121
# ```
#
# Then run the cell below to confirm the GPU is visible.

# %%
# %pip install ultralytics   # only if you are NOT using a venv

import torch
print("torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.140  Python-3.14.7 torch-2.14.0+cu132 CUDA:0 (NVIDIA GeForce RTX 5080, 16303MiB)
# Setup complete  (16 CPUs, 61.6 GB RAM, 1421.1/1906.6 GB disk)

# %% [markdown]
# # Step 2: Point to Your Dataset
#
# Ultralytics uses the same YOLO dataset format as the old v5/v8 notebooks (`images/`, `labels/`, `data.yaml`), so a Roboflow export for v5/v8 works unchanged. Set the path to your dataset's `data.yaml` below. The `train`/`val`/`test` paths inside the yaml are resolved relative to the yaml file itself.

# %%
from pathlib import Path

# Absolute or repo-relative path to your dataset's data.yaml
DATA_YAML = str(Path(r"C:\Users\ryano\Downloads\ntu\SC2079-GROUP31-ImageRec\master_dataset\data_global.yaml").resolve())   # <- change this to your dataset

# Where Ultralytics writes checkpoints (relative to this notebook's working dir)
PROJECT = "runs_4(global)"

print("data.yaml:", DATA_YAML)
print("exists:", Path(DATA_YAML).exists())
# Out:
# data.yaml: C:\Users\ryano\Downloads\ntu\SC2079-GROUP31-ImageRec\master_dataset\data_global.yaml
# exists: True

# %% [markdown]
# # Step 3: Load the Pretrained Starting Point
#
# The first run downloads the chosen checkpoint from the Ultralytics GitHub release and keeps it locally, so later runs are fully offline. Sizes: `yolo26n.pt` `yolo26s.pt` `yolo26m.pt` `yolo26l.pt` `yolo26x.pt`.

# %%
from ultralytics import YOLO

# Pick the biggest size your GPU allows
model = YOLO(r"yolo26s.pt")

# %%
# !nvidia-smi
# Out:
# Mon Sep 14 09:07:59 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 610.62                 KMD Version: 610.62        CUDA UMD Version: 13.3     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5080      WDDM  |   00000000:01:00.0 Off |                  N/A |
# |  0%   39C    P8             27W /  360W |       0MiB /  16303MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # Step 4: Train
#
# - **epochs**: ~20-100 is plenty for this symbol task.
# - **batch**: start with `-1` (auto-picks the largest batch your GPU fits), then set a fixed value such as `128` if you want reproducibility.
# - **imgsz**: `416` (as used in the previous notebooks) or `640`.
# - **fliplr=0.0** is important - horizontal flips would confuse the Left/Right arrow symbols.
# - **resume**: if a run is interrupted, load `runs/train/weights/last.pt` and call `model.train(resume=True)`.
# - Checkpoints are written to `<PROJECT>/train/weights/` as `best.pt` (best validation) and `last.pt` (final epoch).

# %%
model.train(data=DATA_YAML, epochs=20, imgsz=416, batch=-1,
            fliplr=0.0, project=PROJECT, name="train", device=0,resume=False)
# Out:
# C:\Users\ryano\anaconda3\envs\sc2079\Lib\site-packages\requests\__init__.py:92: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# New https://pypi.org/project/ultralytics/8.4.150 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.4.140  Python-3.14.7 torch-2.14.0+cu132 CUDA:0 (NVIDIA GeForce RTX 5080, 16303MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=-1, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=C:\Users\ryano\Downloads\ntu\SC2079-GROUP31-ImageRec\master_dataset\data_global.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.0, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=416, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26s.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=train-6, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs_4(global), quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\ryano\Downloads\ntu\SC2079-GROUP31-ImageRec\Notebooks\Model Training Notebooks\runs\detect\runs_4(global)\train-6, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=41
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    477184  ultralytics.nn.modules.block.C3k2            [768, 256, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    136192  ultralytics.nn.modules.block.C3k2            [512, 128, 1, True]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1843712  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    963598  ultralytics.nn.modules.head.Detect           [41, 1, True, [128, 256, 512]]
# YOLO26s summary: 260 layers, 9,979,598 parameters, 9,979,598 gradients, 22.9 GFLOPs
#
# Transferred 696/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 347.4239.3 MB/s, size: 82.9 KB)
# train: Scanning C:\Users\ryano\Downloads\ntu\SC2079-GROUP31-ImageRec\master_dataset\train\labels.cache... 97389 images, 3017 backgrounds, 1 corrupt: 100% ━━━━━━━━━━━━ 97389/97389 16.3Git/s 0.0s
# train: C:\Users\ryano\Downloads\ntu\SC2079-GROUP31-ImageRec\master_dataset\train\images\rpi-image-7_IMG_1335_JPG.rf.c0fbe915711f64bcf2c9cbed2a8bfbd6.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# WARNING Box and segment counts should be equal, but got len(segments) = 4, len(boxes) = 110157. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# AutoBatch: Computing optimal batch size for imgsz=416 at 60.0% GPU memory utilization.
# AutoBatch: CUDA:0 (NVIDIA GeForce RTX 5080) 15.92G total, 0.13G reserved, 0.11G allocated, 15.68G free
#       Params      GFLOPs  GPU_mem (GB)  forward (ms) backward (ms)                   input                  output
#      9979598       9.576         0.541         53.75           nan        (1, 3, 416, 416)                    list
#      9979598       19.15         0.973         63.65           nan        (2, 3, 416, 416)                    list
#      9979598       38.31         1.502         24.67           nan        (4, 3, 416, 416)                    list
#      9979598       76.61         2.789         30.27           nan        (8, 3, 416, 416)                    list
#      9979598       153.2         5.323         56.79           nan       (16, 3, 416, 416)                    list
# AutoBatch: Using batch-size 27 for CUDA:0 9.03G/15.92G (57%)
# WARNING train: Slow image access detected (ping: 0.10.0 ms, read: 9.715.8 MB/s, size: 96.0 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips
# train: Scanning C:\Users\ryano\Downloads\ntu\SC2079-GROUP31-ImageRec\master_dataset\train\labels.cache... 97389 images, 3017 backgrounds, 1 corrupt: 100% ━━━━━━━━━━━━ 97389/97389 16.3Git/s 0.0s
# train: C:\Users\ryano\Downloads\ntu\SC2079-GROUP31-ImageRec\master_dataset\train\images\rpi-image-7_IMG_1335_JPG.rf.c0fbe915711f64bcf2c9cbed2a8bfbd6.jpg: ignoring corrupt image/label: labels mix segment and detection rows
# WARNING Box and segment counts should be equal, but got len(segments) = 4, len(boxes) = 110157. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Fast image access  (ping: 0.10.0 ms, read: 129.7207.6 MB/s, size: 132.7 KB)
# val: Scanning C:\Users\ryano\Downloads\ntu\SC2079-GROUP31-ImageRec\master_dataset\valid\labels.cache... 15414 images, 448 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 15414/15414 5.9Git/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: MuSGD(lr=0.01, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.000421875), 126 bias(decay=0.0)
# Plotting labels to C:\Users\ryano\Downloads\ntu\SC2079-GROUP31-ImageRec\Notebooks\Model Training Notebooks\runs\detect\runs_4(global)\train-6\labels.jpg...
# Using 97388 train, 15414 val images for fraction=1.0 at imgsz=416
# Using 8 dataloader workers
# Logging results to C:\Users\ryano\Downloads\ntu\SC2079-GROUP31-ImageRec\Notebooks\Model Training Notebooks\runs\detect\runs_4(global)\train-6
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        1/20      3.37G      1.188      2.061   0.008333         37        416: 100% ━━━━━━━━━━━━ 3607/3607 3.9it/s 15:310.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 286/286 8.3it/s 34.4s0.1ss
#                    all      15414      15344      0.898      0.891      0.937      0.703
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        2/20      4.37G      1.064     0.7722   0.007361         42        416: 100% ━━━━━━━━━━━━ 3607/3607 4.1it/s 14:410.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 286/286 9.3it/s 30.6s<0.1ss
#                    all      15414      15344      0.923      0.913      0.944      0.727
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        3/20      4.38G      1.141     0.8007   0.007965         56        416: 100% ━━━━━━━━━━━━ 3607/3607 4.1it/s 14:360.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 286/286 9.3it/s 30.9s0.1sss
#                    all      15414      15344      0.934      0.925      0.944       0.72
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        4/20      4.38G      1.151     0.7456   0.007939         54        416: 100% ━━━━━━━━━━━━ 3607/3607 4.1it/s 14:370.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 286/286 9.3it/s 30.6s0.2sss
#                    all      15414      15344      0.941       0.94      0.952      0.756
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        5/20      4.38G      1.069      0.628   0.007206         45        416: 100% ━━━━━━━━━━━━ 3607/3607 4.1it/s 14:370.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 286/286 9.4it/s 30.5s0.1sss
#                    all      15414      15344      0.946      0.946      0.954       0.77
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        6/20      4.38G      1.022     0.5802    0.00675         51        416: 100% ━━━━━━━━━━━━ 3607/3607 4.1it/s 14:380.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 286/286 9.5it/s 30.0s<0.1ss
#                    all      15414      15344      0.948      0.946      0.954      0.777
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        7/20      4.38G     0.9857     0.5336   0.006423         58        416: 100% ━━━━━━━━━━━━ 3607/3607 4.1it/s 14:440.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 286/286 9.5it/s 30.2s<0.1ss
#                    all      15414      15344      0.949      0.949      0.955      0.788
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        8/20      4.38G     0.9509     0.5083    0.00617         36        416: 100% ━━━━━━━━━━━━ 3607/3607 4.1it/s 14:450.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 286/286 9.5it/s 30.0s<0.1ss
#                    all      15414      15344       0.95      0.948      0.956      0.793
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#        9/20      4.38G     0.9283     0.4869   0.005943         49        416: 47% ━━━━━╸────── 1711/3607 4.0it/s 7:01<7:500
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#       10/20      4.38G     0.9021     0.4626    0.00576         44        416: 100% ━━━━━━━━━━━━ 3607/3607 4.1it/s 14:480.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 286/286 9.3it/s 30.8s<0.2ss
#                    all      15414      15344       0.95      0.947      0.956      0.795
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       11/20      4.38G     0.8324     0.3443   0.006582         26        416: 100% ━━━━━━━━━━━━ 3607/3607 4.1it/s 14:420.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 286/286 9.4it/s 30.4s<0.2ss
#                    all      15414      15344      0.949      0.946      0.956      0.797
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       12/20      4.38G     0.8094     0.3184   0.006437         29        416: 10% ━─────────── 394/3607 4.2it/s 1:37<12:50

# %% [markdown]
# # Step 5: Validate & Test the Trained Model

# %%
# Evaluate the best checkpoint on the validation split
best = YOLO(r"C:\Users\ryano\Downloads\ntu\SC2079-GROUP31-ImageRec\Notebooks\Model Training Notebooks\runs\detect\runs_2(global)\train-4\weights\last.pt")
best.val(data=DATA_YAML)

# Run detection on your test images and save the annotated results
# TEST_SOURCE = str(Path("Week8/test/images").resolve())  # <- point at your test folder
best.predict(source=r"C:\Users\ryano\Downloads\Telegram Desktop\New folder", conf=0.25, save=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Evaluate the best checkpoint on the validation split
#       2 best = YOLO(r"C:\Users\ryano\Downloads\ntu\SC2079-GROUP31-ImageRec\Notebooks\Model Training Notebooks\runs\detect\runs_2(global)\train-4\weights\last.pt")
# ----> 3 best.val(data=DATA_YAML)
#       4
#       5 # Run detection on your test images and save the annotated results
#       6 # TEST_SOURCE = str(Path("Week8/test/images").resolve())  # <- point at your test folder
#
# NameError: name 'DATA_YAML' is not defined

# %%
# Evaluate the best checkpoint on the validation split
best = YOLO(r"C:\Users\ryano\Downloads\ntu\SC2079-GROUP31-ImageRec\Notebooks\Model Training Notebooks\runs\detect\runs_2(global)\train-4\weights\best.pt")
# best.val(data=DATA_YAML)

# Run detection on your test images and save the annotated results
# TEST_SOURCE = str(Path("Week8/test/images").resolve())  # <- point at your test folder
best.predict(source=r"C:\Users\ryano\Downloads\Telegram Desktop\New folder", conf=0.5, save=True)
# Out:
# image 1/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\2.jpg: 320x416 (no detections), 6.5ms
# image 2/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\2b.jpg: 320x416 (no detections), 8.7ms
# image 3/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\2b2.jpg: 320x416 (no detections), 9.3ms
# image 4/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\3b.jpg: 320x416 1 B, 9.2ms
# image 5/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\4b.jpg: 320x416 1 Left, 7.8ms
# image 6/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\5.jpg: 320x416 1 Five, 8.0ms
# image 7/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\7b.jpg: 320x416 1 Seven, 7.4ms
# image 8/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\b.jpg: 320x416 1 B, 9.1ms
# image 9/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\bb.jpg: 320x416 (no detections), 8.9ms
# image 10/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\e.jpg: 320x416 1 B, 8.7ms
# image 11/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\f.jpg: 320x416 (no detections), 9.0ms
# image 12/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\f2.jpg: 320x416 1 B, 6.9ms
# image 13/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\f3.jpg: 320x416 (no detections), 6.9ms
# image 14/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\f4.jpg: 320x416 (no detections), 7.0ms
# image 15/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\fb.jpg: 320x416 1 B, 7.8ms
# image 16/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\h.jpg: 320x416 (no detections), 8.5ms
# image 17/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\imagerectest.jpg: 320x416 1 Four, 9.4ms
# image 18/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\rectest.jpg: 320x416 (no detections), 8.0ms
# image 19/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\w.jpg: 320x416 (no detections), 7.2ms
# Speed: 1.1ms preprocess, 8.1ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 416)
# Results saved to C:\Users\ryano\Downloads\ntu\SC2079-GROUP31-ImageRec\Notebooks\Model Training Notebooks\runs\detect\predict-10
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'unused', 1: 'Box', 2: 'Bullseye', 3: 'NULL', 4: 'unused', 5: 'unused', 6: 'unused', 7: 'unused', 8: 'unused', 9: 'unused', 10: 'unused', 11: 'One', 12: 'Two', 13: 'Three', 14: 'Four', 15: 'Five', 16: 'Six', 17: 'Seven', 18: 'Eight', 19: 'Nine', 20: 'A', 21: 'B', 22: 'C', 23: 'D', 24: 'E', 25: 'F', 26: 'G', 27: 'H', 28: 'S', 29: 'T', 30: 'U', 31: 'V', 32: 'W', 33: 'X', 34: 'Y', 35: 'Z', 36: 'Up', 37: 'Down', 38: 'Right', 39: 'Left', 40: 'Stop'}
#  obb: None
#  orig_img: array([[[124, 140, 122],
#          [127, 143, 126],
#          [125, 142, 128],
#          ...,
#          [144, 150, 155],
#          [146, 149, 157],
#          [153, 156, 164]],
#
#         [[124, 140, 123],
#          [124, 140, 123],
#          [128, 145, 131],
#          ...,
#          [144, 150, 155],
#          [145, 148, 156],
#          [150, 153, 161]],
#
#         [[122, 139, 125],
#          [121, 138, 124],
#          [125, 142, 129],
#          ...,
#          [145, 152, 155],
#          [148, 154, 159],
#          [147, 153, 158]],
#
#         ...,
#
#         [[157, 177, 178],
#          [156, 176, 177],
#          [158, 179, 177],
#          ...,
#          [102, 116, 122],
#          [ 96, 107, 111],
#          [ 96, 105, 108]],
#
#         [[158, 178, 179],
#          [157, 177, 178],
#          [164, 184, 185],
#          ...,
#          [ 99, 109, 116],
#          [ 98, 104, 109],
#          [ 96, 103, 106]],
#
#         [[159, 179, 180],
#          [164, 184, 185],
#          [169, 189, 190],
#          ...,
#          [101, 110, 114],
#          [ 99, 105, 110],
#          [100, 105, 108]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\2.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-10'
#  semantic_mask: None
#  speed: {'preprocess': 1.4264000001276145, 'inference': 6.534500000270782, 'postprocess': 0.26280000020051375},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'unused', 1: 'Box', 2: 'Bullseye', 3: 'NULL', 4: 'unused', 5: 'unused', 6: 'unused', 7: 'unused', 8: 'unused', 9: 'unused', 10: 'unused', 11: 'One', 12: 'Two', 13: 'Three', 14: 'Four', 15: 'Five', 16: 'Six', 17: 'Seven', 18: 'Eight', 19: 'Nine', 20: 'A', 21: 'B', 22: 'C', 23: 'D', 24: 'E', 25: 'F', 26: 'G', 27: 'H', 28: 'S', 29: 'T', 30: 'U', 31: 'V', 32: 'W', 33: 'X', 34: 'Y', 35: 'Z', 36: 'Up', 37: 'Down', 38: 'Right', 39: 'Left', 40: 'Stop'}
#  obb: None
#  orig_img: array([[[125, 145, 146],
#          [125, 145, 146],
#          [132, 148, 147],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[124, 142, 143],
#          [132, 150, 149],
#          [133, 149, 148],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[133, 149, 148],
#          [135, 152, 149],
#          [134, 151, 148],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[174, 173, 183],
#          [176, 175, 185],
#          [177, 178, 188],
#          ...,
#          [ 39,  49,  49],
#          [ 37,  47,  47],
#          [ 37,  47,  47]],
#
#         [[174, 172, 184],
#          [174, 172, 184],
#          [175, 174, 184],
#          ...,
#          [ 41,  54,  52],
#          [ 36,  50,  49],
#          [ 39,  53,  52]],
#
#         [[178, 176, 188],
#          [174, 172, 184],
#          [171, 170, 180],
#          ...,
#          [ 39,  53,  51],
#          [ 38,  54,  53],
#          [ 38,  54,  53]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\2b.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-10'
#  semantic_mask: None
#  speed: {'preprocess': 1.1900999998033512, 'inference': 8.704500000021653, 'postprocess': 0.2890999994633603},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'unused', 1: 'Box', 2: 'Bullseye', 3: 'NULL', 4: 'unused', 5: 'unused', 6: 'unused', 7: 'unused', 8: 'unused', 9: 'unused', 10: 'unused', 11: 'One', 12: 'Two', 13: 'Three', 14: 'Four', 15: 'Five', 16: 'Six', 17: 'Seven', 18: 'Eight', 19: 'Nine', 20: 'A', 21: 'B', 22: 'C', 23: 'D', 24: 'E', 25: 'F', 26: 'G', 27: 'H', 28: 'S', 29: 'T', 30: 'U', 31: 'V', 32: 'W', 33: 'X', 34: 'Y', 35: 'Z', 36: 'Up', 37: 'Down', 38: 'Right', 39: 'Left', 40: 'Stop'}
#  obb: None
#  orig_img: array([[[143, 151, 158],
#          [141, 149, 156],
#          [147, 158, 162],
#          ...,
#          [143, 157, 156],
#          [144, 161, 158],
#          [143, 160, 157]],
#
#         [[144, 152, 159],
#          [147, 155, 162],
#          [150, 159, 163],
#          ...,
#          [146, 160, 159],
#          [148, 162, 160],
#          [145, 162, 159]],
#
#         [[148, 154, 161],
#          [148, 156, 163],
#          [144, 152, 159],
#          ...,
#          [146, 159, 157],
#          [150, 162, 162],
#          [151, 165, 164]],
#
#         ...,
#
#         [[148, 167, 175],
#          [153, 172, 180],
#          [157, 175, 186],
#          ...,
#          [ 48,  40,  23],
#          [ 48,  41,  22],
#          [ 47,  41,  22]],
#
#         [[153, 169, 181],
#          [153, 169, 181],
#          [148, 166, 177],
#          ...,
#          [ 57,  49,  32],
#          [ 54,  47,  28],
#          [ 52,  45,  25]],
#
#         [[155, 169, 181],
#          [152, 168, 180],
#          [142, 158, 170],
#          ...,
#          [ 59,  49,  31],
#          [ 57,  50,  31],
#          [ 55,  48,  28]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\2b2.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-10'
#  semantic_mask: None
#  speed: {'preprocess': 1.012099999570637, 'inference': 9.304500000325788, 'postprocess': 0.31290000060835155},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'unused', 1: 'Box', 2: 'Bullseye', 3: 'NULL', 4: 'unused', 5: 'unused', 6: 'unused', 7: 'unused', 8: 'unused', 9: 'unused', 10: 'unused', 11: 'One', 12: 'Two', 13: 'Three', 14: 'Four', 15: 'Five', 16: 'Six', 17: 'Seven', 18: 'Eight', 19: 'Nine', 20: 'A', 21: 'B', 22: 'C', 23: 'D', 24: 'E', 25: 'F', 26: 'G', 27: 'H', 28: 'S', 29: 'T', 30: 'U', 31: 'V', 32: 'W', 33: 'X', 34: 'Y', 35: 'Z', 36: 'Up', 37: 'Down', 38: 'Right', 39: 'Left', 40: 'Stop'}
#  obb: None
#  orig_img: array([[[134, 150, 149],
#          [136, 152, 151],
#          [128, 146, 145],
#          ...,
#          [147, 159, 159],
#          [145, 157, 159],
#          [142, 154, 156]],
#
#         [[132, 148, 147],
#          [132, 150, 149],
#          [128, 146, 145],
#          ...,
#          [144, 156, 156],
#          [145, 157, 159],
#          [145, 157, 159]],
#
#         [[130, 149, 146],
#          [129, 148, 145],
#          [128, 147, 144],
#          ...,
#          [142, 155, 157],
#          [144, 157, 159],
#          [145, 158, 160]],
#
#         ...,
#
#         [[171, 180, 193],
#          [174, 186, 198],
#          [173, 185, 195],
#          ...,
#          [ 66,  80,  86],
#          [ 68,  84,  91],
#          [ 66,  82,  89]],
#
#         [[172, 179, 194],
#          [169, 178, 191],
#          [175, 185, 195],
#          ...,
#          [ 64,  81,  84],
#          [ 67,  83,  89],
#          [ 67,  83,  89]],
#
#         [[172, 179, 194],
#          [172, 180, 193],
#          [171, 180, 193],
#          ...,
#          [ 64,  81,  84],
#          [ 65,  81,  87],
#          [ 66,  82,  88]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\3b.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-10'
#  semantic_mask: None
#  speed: {'preprocess': 2.4043000003075576, 'inference': 9.19270000031247, 'postprocess': 0.4608999997799401},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'unused', 1: 'Box', 2: 'Bullseye', 3: 'NULL', 4: 'unused', 5: 'unused', 6: 'unused', 7: 'unused', 8: 'unused', 9: 'unused', 10: 'unused', 11: 'One', 12: 'Two', 13: 'Three', 14: 'Four', 15: 'Five', 16: 'Six', 17: 'Seven', 18: 'Eight', 19: 'Nine', 20: 'A', 21: 'B', 22: 'C', 23: 'D', 24: 'E', 25: 'F', 26: 'G', 27: 'H', 28: 'S', 29: 'T', 30: 'U', 31: 'V', 32: 'W', 33: 'X', 34: 'Y', 35: 'Z', 36: 'Up', 37: 'Down', 38: 'Right', 39: 'Left', 40: 'Stop'}
#  obb: None
#  orig_img: array([[[152, 166, 165],
#          [150, 164, 163],
#          [145, 159, 158],
#          ...,
#          [144, 160, 167],
#          [141, 159, 166],
#          [140, 158, 165]],
#
#         [[155, 167, 167],
#          [148, 160, 160],
#          [145, 159, 158],
#          ...,
#          [147, 163, 169],
#          [141, 159, 166],
#          [141, 160, 165]],
#
#         [[149, 158, 161],
#          [149, 158, 161],
#          [153, 165, 167],
#          ...,
#          [146, 165, 168],
#          [144, 163, 168],
#          [145, 164, 167]],
#
#         ...,
#
#         [[151, 159, 172],
#          [146, 155, 165],
#          [147, 155, 168],
#          ...,
#          [ 83, 106, 108],
#          [ 84, 106, 111],
#          [ 84, 107, 109]],
#
#         [[153, 162, 176],
#          [153, 162, 175],
#          [146, 155, 169],
#          ...,
#          [ 85, 105, 110],
#          [ 87, 105, 112],
#          [ 86, 105, 110]],
#
#         [[147, 158, 172],
#          [151, 162, 176],
#          [149, 158, 172],
#          ...,
#          [ 87, 105, 112],
#          [ 90, 106, 113],
#          [ 90, 106, 113]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\4b.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-10'
#  semantic_mask: None
#  speed: {'preprocess': 1.1106000001745997, 'inference': 7.8269999994518, 'postprocess': 0.4183999999440857},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'unused', 1: 'Box', 2: 'Bullseye', 3: 'NULL', 4: 'unused', 5: 'unused', 6: 'unused', 7: 'unused', 8: 'unused', 9: 'unused', 10: 'unused', 11: 'One', 12: 'Two', 13: 'Three', 14: 'Four', 15: 'Five', 16: 'Six', 17: 'Seven', 18: 'Eight', 19: 'Nine', 20: 'A', 21: 'B', 22: 'C', 23: 'D', 24: 'E', 25: 'F', 26: 'G', 27: 'H', 28: 'S', 29: 'T', 30: 'U', 31: 'V', 32: 'W', 33: 'X', 34: 'Y', 35: 'Z', 36: 'Up', 37: 'Down', 38: 'Right', 39: 'Left', 40: 'Stop'}
#  obb: None
#  orig_img: array([[[133, 150, 141],
#          [130, 147, 138],
#          [133, 145, 139],
#          ...,
#          [146, 146, 158],
#          [140, 141, 151],
#          [139, 140, 150]],
#
#         [[134, 151, 142],
#          [134, 151, 142],
#          [131, 145, 139],
#          ...,
#          [143, 144, 154],
#          [140, 141, 151],
#          [139, 140, 150]],
#
#         [[130, 148, 141],
#          [132, 150, 143],
#          [123, 141, 134],
#          ...,
#          [135, 137, 147],
#          [137, 139, 149],
#          [140, 143, 151]],
#
#         ...,
#
#         [[176, 188, 194],
#          [178, 190, 196],
#          [174, 186, 190],
#          ...,
#          [195, 204, 208],
#          [195, 203, 210],
#          [195, 203, 210]],
#
#         [[176, 186, 193],
#          [175, 185, 192],
#          [177, 187, 194],
#          ...,
#          [197, 203, 208],
#          [195, 204, 208],
#          [195, 204, 208]],
#
#         [[176, 186, 193],
#          [176, 186, 193],
#          [176, 186, 193],
#          ...,
#          [197, 203, 208],
#          [195, 204, 208],
#          [195, 204, 208]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\5.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-10'
#  semantic_mask: None
#  speed: {'preprocess': 1.0341999995944207, 'inference': 7.970900000145775, 'postprocess': 0.4166999997323728},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'unused', 1: 'Box', 2: 'Bullseye', 3: 'NULL', 4: 'unused', 5: 'unused', 6: 'unused', 7: 'unused', 8: 'unused', 9: 'unused', 10: 'unused', 11: 'One', 12: 'Two', 13: 'Three', 14: 'Four', 15: 'Five', 16: 'Six', 17: 'Seven', 18: 'Eight', 19: 'Nine', 20: 'A', 21: 'B', 22: 'C', 23: 'D', 24: 'E', 25: 'F', 26: 'G', 27: 'H', 28: 'S', 29: 'T', 30: 'U', 31: 'V', 32: 'W', 33: 'X', 34: 'Y', 35: 'Z', 36: 'Up', 37: 'Down', 38: 'Right', 39: 'Left', 40: 'Stop'}
#  obb: None
#  orig_img: array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [126, 139, 141],
#          [136, 148, 150],
#          [134, 143, 146]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [131, 146, 148],
#          [133, 146, 148],
#          [134, 146, 148]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [128, 146, 147],
#          [133, 148, 150],
#          [136, 151, 153]],
#
#         ...,
#
#         [[ 33,  39,  44],
#          [ 34,  40,  45],
#          [ 41,  47,  54],
#          ...,
#          [ 38,  50,  60],
#          [ 35,  45,  55],
#          [ 36,  46,  56]],
#
#         [[ 31,  38,  41],
#          [ 36,  43,  46],
#          [ 43,  47,  52],
#          ...,
#          [ 38,  44,  57],
#          [ 40,  43,  57],
#          [ 37,  38,  52]],
#
#         [[ 29,  36,  39],
#          [ 35,  42,  45],
#          [ 42,  46,  51],
#          ...,
#          [ 43,  44,  58],
#          [ 39,  39,  53],
#          [ 41,  38,  53]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\7b.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-10'
#  semantic_mask: None
#  speed: {'preprocess': 0.8174000004146365, 'inference': 7.380700000794604, 'postprocess': 0.37460000021383166},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'unused', 1: 'Box', 2: 'Bullseye', 3: 'NULL', 4: 'unused', 5: 'unused', 6: 'unused', 7: 'unused', 8: 'unused', 9: 'unused', 10: 'unused', 11: 'One', 12: 'Two', 13: 'Three', 14: 'Four', 15: 'Five', 16: 'Six', 17: 'Seven', 18: 'Eight', 19: 'Nine', 20: 'A', 21: 'B', 22: 'C', 23: 'D', 24: 'E', 25: 'F', 26: 'G', 27: 'H', 28: 'S', 29: 'T', 30: 'U', 31: 'V', 32: 'W', 33: 'X', 34: 'Y', 35: 'Z', 36: 'Up', 37: 'Down', 38: 'Right', 39: 'Left', 40: 'Stop'}
#  obb: None
#  orig_img: array([[[123, 135, 135],
#          [127, 140, 138],
#          [132, 146, 144],
#          ...,
#          [135, 140, 141],
#          [132, 137, 140],
#          [130, 135, 138]],
#
#         [[123, 135, 135],
#          [130, 142, 142],
#          [136, 150, 148],
#          ...,
#          [135, 140, 141],
#          [132, 137, 140],
#          [133, 138, 141]],
#
#         [[130, 142, 142],
#          [131, 143, 143],
#          [133, 146, 144],
#          ...,
#          [133, 141, 141],
#          [138, 145, 148],
#          [140, 147, 150]],
#
#         ...,
#
#         [[176, 183, 192],
#          [174, 181, 190],
#          [177, 183, 190],
#          ...,
#          [155, 168, 176],
#          [150, 164, 170],
#          [154, 168, 174]],
#
#         [[181, 183, 193],
#          [180, 182, 192],
#          [185, 187, 195],
#          ...,
#          [155, 169, 175],
#          [156, 168, 174],
#          [157, 169, 175]],
#
#         [[178, 179, 189],
#          [183, 184, 194],
#          [188, 187, 196],
#          ...,
#          [155, 169, 175],
#          [157, 169, 175],
#          [158, 170, 176]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\b.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-10'
#  semantic_mask: None
#  speed: {'preprocess': 1.0488999996596249, 'inference': 9.093700000448734, 'postprocess': 0.3974999999627471},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'unused', 1: 'Box', 2: 'Bullseye', 3: 'NULL', 4: 'unused', 5: 'unused', 6: 'unused', 7: 'unused', 8: 'unused', 9: 'unused', 10: 'unused', 11: 'One', 12: 'Two', 13: 'Three', 14: 'Four', 15: 'Five', 16: 'Six', 17: 'Seven', 18: 'Eight', 19: 'Nine', 20: 'A', 21: 'B', 22: 'C', 23: 'D', 24: 'E', 25: 'F', 26: 'G', 27: 'H', 28: 'S', 29: 'T', 30: 'U', 31: 'V', 32: 'W', 33: 'X', 34: 'Y', 35: 'Z', 36: 'Up', 37: 'Down', 38: 'Right', 39: 'Left', 40: 'Stop'}
#  obb: None
#  orig_img: array([[[134, 145, 143],
#          [137, 150, 148],
#          [146, 158, 158],
#          ...,
#          [150, 156, 167],
#          [150, 151, 165],
#          [152, 151, 167]],
#
#         [[134, 145, 143],
#          [140, 151, 149],
#          [147, 159, 159],
#          ...,
#          [154, 160, 171],
#          [147, 150, 164],
#          [152, 153, 167]],
#
#         [[138, 149, 146],
#          [140, 151, 148],
#          [143, 154, 152],
#          ...,
#          [151, 160, 169],
#          [147, 153, 164],
#          [153, 157, 168]],
#
#         ...,
#
#         [[186, 193, 202],
#          [186, 193, 202],
#          [186, 191, 200],
#          ...,
#          [ 21,  19,  25],
#          [ 27,  25,  31],
#          [ 31,  29,  35]],
#
#         [[191, 196, 205],
#          [191, 196, 205],
#          [188, 193, 202],
#          ...,
#          [ 23,  18,  27],
#          [ 26,  22,  33],
#          [ 33,  29,  40]],
#
#         [[187, 192, 201],
#          [191, 196, 205],
#          [192, 197, 206],
#          ...,
#          [ 27,  22,  31],
#          [ 28,  24,  36],
#          [ 31,  27,  39]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\bb.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-10'
#  semantic_mask: None
#  speed: {'preprocess': 1.5868000000409666, 'inference': 8.946500000092783, 'postprocess': 0.32869999995455146},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'unused', 1: 'Box', 2: 'Bullseye', 3: 'NULL', 4: 'unused', 5: 'unused', 6: 'unused', 7: 'unused', 8: 'unused', 9: 'unused', 10: 'unused', 11: 'One', 12: 'Two', 13: 'Three', 14: 'Four', 15: 'Five', 16: 'Six', 17: 'Seven', 18: 'Eight', 19: 'Nine', 20: 'A', 21: 'B', 22: 'C', 23: 'D', 24: 'E', 25: 'F', 26: 'G', 27: 'H', 28: 'S', 29: 'T', 30: 'U', 31: 'V', 32: 'W', 33: 'X', 34: 'Y', 35: 'Z', 36: 'Up', 37: 'Down', 38: 'Right', 39: 'Left', 40: 'Stop'}
#  obb: None
#  orig_img: array([[[114, 122, 115],
#          [113, 121, 114],
#          [112, 119, 114],
#          ...,
#          [126, 138, 142],
#          [129, 140, 148],
#          [127, 140, 148]],
#
#         [[113, 121, 114],
#          [115, 123, 116],
#          [110, 121, 113],
#          ...,
#          [127, 139, 143],
#          [127, 141, 147],
#          [128, 142, 148]],
#
#         [[116, 127, 117],
#          [117, 128, 118],
#          [115, 129, 118],
#          ...,
#          [127, 140, 142],
#          [128, 143, 145],
#          [127, 144, 147]],
#
#         ...,
#
#         [[ 37,  58,  50],
#          [ 37,  55,  48],
#          [ 43,  59,  52],
#          ...,
#          [172, 188, 195],
#          [169, 182, 190],
#          [170, 184, 190]],
#
#         [[ 31,  61,  50],
#          [ 36,  63,  53],
#          [ 32,  57,  47],
#          ...,
#          [177, 189, 199],
#          [174, 187, 195],
#          [173, 186, 194]],
#
#         [[ 28,  62,  51],
#          [ 31,  63,  52],
#          [ 31,  61,  50],
#          ...,
#          [176, 188, 198],
#          [172, 184, 194],
#          [173, 186, 194]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\e.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-10'
#  semantic_mask: None
#  speed: {'preprocess': 0.9481000006417162, 'inference': 8.71519999964221, 'postprocess': 0.47220000033121323},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'unused', 1: 'Box', 2: 'Bullseye', 3: 'NULL', 4: 'unused', 5: 'unused', 6: 'unused', 7: 'unused', 8: 'unused', 9: 'unused', 10: 'unused', 11: 'One', 12: 'Two', 13: 'Three', 14: 'Four', 15: 'Five', 16: 'Six', 17: 'Seven', 18: 'Eight', 19: 'Nine', 20: 'A', 21: 'B', 22: 'C', 23: 'D', 24: 'E', 25: 'F', 26: 'G', 27: 'H', 28: 'S', 29: 'T', 30: 'U', 31: 'V', 32: 'W', 33: 'X', 34: 'Y', 35: 'Z', 36: 'Up', 37: 'Down', 38: 'Right', 39: 'Left', 40: 'Stop'}
#  obb: None
#  orig_img: array([[[ 52,  70,  53],
#          [ 54,  71,  57],
#          [ 53,  71,  58],
#          ...,
#          [124, 138, 137],
#          [133, 147, 145],
#          [137, 151, 149]],
#
#         [[ 55,  71,  54],
#          [ 55,  70,  56],
#          [ 55,  72,  59],
#          ...,
#          [129, 143, 142],
#          [134, 148, 146],
#          [138, 152, 150]],
#
#         [[ 60,  71,  55],
#          [ 57,  70,  56],
#          [ 56,  70,  58],
#          ...,
#          [131, 145, 144],
#          [135, 149, 148],
#          [137, 151, 150]],
#
#         ...,
#
#         [[101, 102,  98],
#          [ 98,  99,  95],
#          [ 98,  99,  95],
#          ...,
#          [ 60,  74,  72],
#          [ 67,  81,  77],
#          [ 69,  83,  79]],
#
#         [[ 96,  94,  93],
#          [ 94,  92,  91],
#          [ 99,  97,  96],
#          ...,
#          [ 65,  79,  77],
#          [ 69,  83,  81],
#          [ 73,  87,  85]],
#
#         [[ 98,  96,  96],
#          [ 97,  95,  95],
#          [100,  98,  97],
#          ...,
#          [ 67,  84,  81],
#          [ 73,  87,  85],
#          [ 73,  87,  85]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\f.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-10'
#  semantic_mask: None
#  speed: {'preprocess': 0.9840000002441229, 'inference': 8.972000000539992, 'postprocess': 0.33069999972212827},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'unused', 1: 'Box', 2: 'Bullseye', 3: 'NULL', 4: 'unused', 5: 'unused', 6: 'unused', 7: 'unused', 8: 'unused', 9: 'unused', 10: 'unused', 11: 'One', 12: 'Two', 13: 'Three', 14: 'Four', 15: 'Five', 16: 'Six', 17: 'Seven', 18: 'Eight', 19: 'Nine', 20: 'A', 21: 'B', 22: 'C', 23: 'D', 24: 'E', 25: 'F', 26: 'G', 27: 'H', 28: 'S', 29: 'T', 30: 'U', 31: 'V', 32: 'W', 33: 'X', 34: 'Y', 35: 'Z', 36: 'Up', 37: 'Down', 38: 'Right', 39: 'Left', 40: 'Stop'}
#  obb: None
#  orig_img: array([[[112, 141, 138],
#          [116, 143, 140],
#          [121, 143, 141],
#          ...,
#          [113, 123, 123],
#          [114, 127, 125],
#          [116, 129, 127]],
#
#         [[113, 140, 137],
#          [119, 143, 141],
#          [123, 144, 142],
#          ...,
#          [113, 125, 125],
#          [114, 126, 126],
#          [114, 127, 125]],
#
#         [[116, 139, 135],
#          [119, 140, 137],
#          [120, 139, 136],
#          ...,
#          [119, 131, 133],
#          [113, 125, 127],
#          [108, 122, 121]],
#
#         ...,
#
#         [[195, 207, 207],
#          [192, 204, 204],
#          [183, 195, 197],
#          ...,
#          [201, 209, 216],
#          [203, 211, 218],
#          [203, 211, 218]],
#
#         [[186, 199, 201],
#          [186, 199, 201],
#          [178, 191, 193],
#          ...,
#          [203, 212, 216],
#          [203, 211, 218],
#          [204, 212, 219]],
#
#         [[186, 201, 203],
#          [184, 199, 201],
#          [178, 191, 193],
#          ...,
#          [203, 212, 216],
#          [205, 213, 220],
#          [206, 214, 221]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\f2.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-10'
#  semantic_mask: None
#  speed: {'preprocess': 0.9202000001096167, 'inference': 6.8504000000757514, 'postprocess': 0.35649999972520163},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'unused', 1: 'Box', 2: 'Bullseye', 3: 'NULL', 4: 'unused', 5: 'unused', 6: 'unused', 7: 'unused', 8: 'unused', 9: 'unused', 10: 'unused', 11: 'One', 12: 'Two', 13: 'Three', 14: 'Four', 15: 'Five', 16: 'Six', 17: 'Seven', 18: 'Eight', 19: 'Nine', 20: 'A', 21: 'B', 22: 'C', 23: 'D', 24: 'E', 25: 'F', 26: 'G', 27: 'H', 28: 'S', 29: 'T', 30: 'U', 31: 'V', 32: 'W', 33: 'X', 34: 'Y', 35: 'Z', 36: 'Up', 37: 'Down', 38: 'Right', 39: 'Left', 40: 'Stop'}
#  obb: None
#  orig_img: array([[[ 48,  38,  38],
#          [ 43,  35,  35],
#          [ 45,  37,  38],
#          ...,
#          [198, 197, 207],
#          [203, 199, 211],
#          [205, 201, 213]],
#
#         [[ 50,  40,  40],
#          [ 46,  38,  38],
#          [ 43,  37,  38],
#          ...,
#          [199, 198, 208],
#          [203, 199, 211],
#          [205, 201, 213]],
#
#         [[ 52,  44,  45],
#          [ 50,  44,  45],
#          [ 42,  40,  40],
#          ...,
#          [198, 197, 206],
#          [204, 200, 211],
#          [208, 204, 215]],
#
#         ...,
#
#         [[221, 236, 239],
#          [219, 234, 237],
#          [221, 233, 237],
#          ...,
#          [ 60,  79,  82],
#          [ 64,  81,  84],
#          [ 66,  83,  86]],
#
#         [[218, 232, 238],
#          [217, 231, 237],
#          [220, 232, 238],
#          ...,
#          [ 62,  82,  83],
#          [ 59,  79,  80],
#          [ 62,  82,  83]],
#
#         [[216, 230, 236],
#          [218, 232, 238],
#          [221, 233, 239],
#          ...,
#          [ 62,  83,  81],
#          [ 55,  76,  74],
#          [ 59,  80,  78]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\f3.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-10'
#  semantic_mask: None
#  speed: {'preprocess': 0.7669000005989801, 'inference': 6.939200000488199, 'postprocess': 0.2465999996275059},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'unused', 1: 'Box', 2: 'Bullseye', 3: 'NULL', 4: 'unused', 5: 'unused', 6: 'unused', 7: 'unused', 8: 'unused', 9: 'unused', 10: 'unused', 11: 'One', 12: 'Two', 13: 'Three', 14: 'Four', 15: 'Five', 16: 'Six', 17: 'Seven', 18: 'Eight', 19: 'Nine', 20: 'A', 21: 'B', 22: 'C', 23: 'D', 24: 'E', 25: 'F', 26: 'G', 27: 'H', 28: 'S', 29: 'T', 30: 'U', 31: 'V', 32: 'W', 33: 'X', 34: 'Y', 35: 'Z', 36: 'Up', 37: 'Down', 38: 'Right', 39: 'Left', 40: 'Stop'}
#  obb: None
#  orig_img: array([[[ 65,  59,  60],
#          [ 64,  58,  59],
#          [ 70,  59,  62],
#          ...,
#          [143, 152, 155],
#          [147, 156, 159],
#          [146, 155, 158]],
#
#         [[ 65,  59,  60],
#          [ 66,  60,  61],
#          [ 70,  61,  64],
#          ...,
#          [143, 152, 155],
#          [146, 155, 158],
#          [146, 155, 158]],
#
#         [[ 70,  65,  66],
#          [ 74,  68,  69],
#          [ 70,  64,  65],
#          ...,
#          [142, 151, 154],
#          [142, 151, 154],
#          [145, 154, 157]],
#
#         ...,
#
#         [[167, 176, 190],
#          [170, 179, 193],
#          [170, 179, 192],
#          ...,
#          [201, 207, 212],
#          [204, 210, 215],
#          [206, 212, 217]],
#
#         [[163, 175, 187],
#          [164, 176, 188],
#          [166, 178, 190],
#          ...,
#          [201, 210, 214],
#          [205, 211, 216],
#          [206, 212, 217]],
#
#         [[160, 172, 184],
#          [162, 174, 186],
#          [161, 173, 185],
#          ...,
#          [201, 210, 214],
#          [205, 211, 216],
#          [205, 211, 216]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\f4.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-10'
#  semantic_mask: None
#  speed: {'preprocess': 1.0354999994888203, 'inference': 6.979300000239164, 'postprocess': 0.255299999480485},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'unused', 1: 'Box', 2: 'Bullseye', 3: 'NULL', 4: 'unused', 5: 'unused', 6: 'unused', 7: 'unused', 8: 'unused', 9: 'unused', 10: 'unused', 11: 'One', 12: 'Two', 13: 'Three', 14: 'Four', 15: 'Five', 16: 'Six', 17: 'Seven', 18: 'Eight', 19: 'Nine', 20: 'A', 21: 'B', 22: 'C', 23: 'D', 24: 'E', 25: 'F', 26: 'G', 27: 'H', 28: 'S', 29: 'T', 30: 'U', 31: 'V', 32: 'W', 33: 'X', 34: 'Y', 35: 'Z', 36: 'Up', 37: 'Down', 38: 'Right', 39: 'Left', 40: 'Stop'}
#  obb: None
#  orig_img: array([[[123, 144, 136],
#          [126, 147, 139],
#          [120, 141, 133],
#          ...,
#          [136, 156, 157],
#          [136, 156, 157],
#          [128, 148, 149]],
#
#         [[123, 143, 138],
#          [122, 143, 135],
#          [120, 141, 133],
#          ...,
#          [136, 156, 157],
#          [135, 155, 156],
#          [134, 154, 155]],
#
#         [[118, 137, 134],
#          [118, 138, 133],
#          [119, 136, 132],
#          ...,
#          [134, 154, 155],
#          [135, 154, 157],
#          [143, 162, 165]],
#
#         ...,
#
#         [[237, 248, 246],
#          [239, 250, 248],
#          [241, 252, 250],
#          ...,
#          [ 74,  86,  88],
#          [ 96, 108, 112],
#          [ 97, 111, 117]],
#
#         [[242, 255, 253],
#          [242, 255, 253],
#          [243, 255, 253],
#          ...,
#          [ 73,  85,  87],
#          [ 91, 103, 109],
#          [ 97, 110, 118]],
#
#         [[241, 255, 253],
#          [242, 255, 254],
#          [242, 255, 252],
#          ...,
#          [ 74,  86,  88],
#          [ 88, 100, 106],
#          [ 98, 111, 119]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\fb.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-10'
#  semantic_mask: None
#  speed: {'preprocess': 0.9522000000288244, 'inference': 7.78470000022935, 'postprocess': 0.49949999993259553},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'unused', 1: 'Box', 2: 'Bullseye', 3: 'NULL', 4: 'unused', 5: 'unused', 6: 'unused', 7: 'unused', 8: 'unused', 9: 'unused', 10: 'unused', 11: 'One', 12: 'Two', 13: 'Three', 14: 'Four', 15: 'Five', 16: 'Six', 17: 'Seven', 18: 'Eight', 19: 'Nine', 20: 'A', 21: 'B', 22: 'C', 23: 'D', 24: 'E', 25: 'F', 26: 'G', 27: 'H', 28: 'S', 29: 'T', 30: 'U', 31: 'V', 32: 'W', 33: 'X', 34: 'Y', 35: 'Z', 36: 'Up', 37: 'Down', 38: 'Right', 39: 'Left', 40: 'Stop'}
#  obb: None
#  orig_img: array([[[ 40,  49,  52],
#          [ 43,  52,  55],
#          [ 41,  51,  51],
#          ...,
#          [146, 154, 144],
#          [147, 155, 144],
#          [149, 157, 146]],
#
#         [[ 38,  47,  50],
#          [ 41,  50,  53],
#          [ 42,  51,  54],
#          ...,
#          [147, 155, 145],
#          [146, 154, 144],
#          [146, 155, 145]],
#
#         [[ 44,  50,  55],
#          [ 45,  51,  56],
#          [ 42,  48,  53],
#          ...,
#          [145, 152, 145],
#          [143, 151, 144],
#          [139, 150, 142]],
#
#         ...,
#
#         [[171, 181, 191],
#          [169, 179, 189],
#          [169, 179, 189],
#          ...,
#          [ 11,  12,  10],
#          [ 11,  12,  10],
#          [  9,  10,   8]],
#
#         [[171, 180, 189],
#          [171, 180, 189],
#          [170, 181, 189],
#          ...,
#          [ 13,  12,   8],
#          [ 12,  10,   9],
#          [  9,   7,   6]],
#
#         [[172, 181, 190],
#          [172, 181, 190],
#          [169, 180, 188],
#          ...,
#          [ 11,  10,   6],
#          [  9,   7,   6],
#          [ 10,   8,   7]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\h.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-10'
#  semantic_mask: None
#  speed: {'preprocess': 1.2023999997836654, 'inference': 8.48859999950946, 'postprocess': 0.3301999995528604},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'unused', 1: 'Box', 2: 'Bullseye', 3: 'NULL', 4: 'unused', 5: 'unused', 6: 'unused', 7: 'unused', 8: 'unused', 9: 'unused', 10: 'unused', 11: 'One', 12: 'Two', 13: 'Three', 14: 'Four', 15: 'Five', 16: 'Six', 17: 'Seven', 18: 'Eight', 19: 'Nine', 20: 'A', 21: 'B', 22: 'C', 23: 'D', 24: 'E', 25: 'F', 26: 'G', 27: 'H', 28: 'S', 29: 'T', 30: 'U', 31: 'V', 32: 'W', 33: 'X', 34: 'Y', 35: 'Z', 36: 'Up', 37: 'Down', 38: 'Right', 39: 'Left', 40: 'Stop'}
#  obb: None
#  orig_img: array([[[125, 132, 135],
#          [123, 130, 133],
#          [124, 133, 137],
#          ...,
#          [156, 158, 168],
#          [157, 159, 169],
#          [161, 163, 173]],
#
#         [[124, 131, 134],
#          [130, 137, 140],
#          [127, 136, 140],
#          ...,
#          [156, 158, 168],
#          [157, 159, 169],
#          [158, 160, 170]],
#
#         [[130, 138, 138],
#          [130, 138, 138],
#          [123, 132, 135],
#          ...,
#          [156, 159, 167],
#          [156, 162, 169],
#          [156, 162, 169]],
#
#         ...,
#
#         [[198, 206, 213],
#          [201, 209, 216],
#          [202, 210, 217],
#          ...,
#          [175, 192, 195],
#          [178, 193, 196],
#          [175, 192, 195]],
#
#         [[192, 203, 207],
#          [192, 203, 207],
#          [199, 208, 212],
#          ...,
#          [168, 187, 190],
#          [172, 189, 192],
#          [174, 193, 196]],
#
#         [[189, 200, 204],
#          [191, 202, 206],
#          [197, 206, 210],
#          ...,
#          [169, 188, 191],
#          [168, 187, 190],
#          [174, 193, 196]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\imagerectest.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-10'
#  semantic_mask: None
#  speed: {'preprocess': 0.8766999999352265, 'inference': 9.400399999321962, 'postprocess': 0.4934999997203704},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'unused', 1: 'Box', 2: 'Bullseye', 3: 'NULL', 4: 'unused', 5: 'unused', 6: 'unused', 7: 'unused', 8: 'unused', 9: 'unused', 10: 'unused', 11: 'One', 12: 'Two', 13: 'Three', 14: 'Four', 15: 'Five', 16: 'Six', 17: 'Seven', 18: 'Eight', 19: 'Nine', 20: 'A', 21: 'B', 22: 'C', 23: 'D', 24: 'E', 25: 'F', 26: 'G', 27: 'H', 28: 'S', 29: 'T', 30: 'U', 31: 'V', 32: 'W', 33: 'X', 34: 'Y', 35: 'Z', 36: 'Up', 37: 'Down', 38: 'Right', 39: 'Left', 40: 'Stop'}
#  obb: None
#  orig_img: array([[[ 79,  89,  83],
#          [ 80,  90,  84],
#          [ 80,  90,  84],
#          ...,
#          [142, 153, 150],
#          [146, 157, 155],
#          [142, 153, 151]],
#
#         [[ 79,  86,  81],
#          [ 80,  90,  84],
#          [ 82,  89,  84],
#          ...,
#          [146, 159, 157],
#          [148, 159, 157],
#          [145, 158, 156]],
#
#         [[ 83,  90,  83],
#          [ 79,  87,  80],
#          [ 77,  83,  78],
#          ...,
#          [151, 165, 163],
#          [147, 160, 158],
#          [144, 158, 156]],
#
#         ...,
#
#         [[ 73,  73,  89],
#          [ 81,  84,  98],
#          [ 80,  85,  94],
#          ...,
#          [ 57,  76,  79],
#          [ 62,  81,  84],
#          [ 60,  81,  82]],
#
#         [[ 74,  73,  89],
#          [ 73,  73,  87],
#          [ 79,  81,  91],
#          ...,
#          [ 52,  73,  75],
#          [ 54,  75,  77],
#          [ 54,  77,  79]],
#
#         [[ 73,  70,  86],
#          [ 73,  73,  87],
#          [ 74,  75,  85],
#          ...,
#          [ 50,  71,  73],
#          [ 46,  69,  71],
#          [ 50,  73,  75]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\rectest.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-10'
#  semantic_mask: None
#  speed: {'preprocess': 1.0746999996626982, 'inference': 8.002900000064983, 'postprocess': 0.39319999996223487},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'unused', 1: 'Box', 2: 'Bullseye', 3: 'NULL', 4: 'unused', 5: 'unused', 6: 'unused', 7: 'unused', 8: 'unused', 9: 'unused', 10: 'unused', 11: 'One', 12: 'Two', 13: 'Three', 14: 'Four', 15: 'Five', 16: 'Six', 17: 'Seven', 18: 'Eight', 19: 'Nine', 20: 'A', 21: 'B', 22: 'C', 23: 'D', 24: 'E', 25: 'F', 26: 'G', 27: 'H', 28: 'S', 29: 'T', 30: 'U', 31: 'V', 32: 'W', 33: 'X', 34: 'Y', 35: 'Z', 36: 'Up', 37: 'Down', 38: 'Right', 39: 'Left', 40: 'Stop'}
#  obb: None
#  orig_img: array([[[130, 160, 155],
#          [137, 164, 160],
#          [137, 163, 157],
#          ...,
#          [ 83,  87,  82],
#          [ 79,  83,  77],
#          [ 79,  83,  77]],
#
#         [[133, 158, 154],
#          [133, 158, 154],
#          [139, 162, 158],
#          ...,
#          [ 80,  84,  79],
#          [ 77,  81,  76],
#          [ 78,  82,  77]],
#
#         [[144, 162, 161],
#          [143, 162, 159],
#          [144, 161, 158],
#          ...,
#          [ 80,  82,  82],
#          [ 82,  82,  82],
#          [ 78,  79,  77]],
#
#         ...,
#
#         [[187, 193, 206],
#          [189, 195, 208],
#          [194, 200, 211],
#          ...,
#          [169, 183, 195],
#          [171, 185, 197],
#          [174, 190, 203]],
#
#         [[190, 196, 207],
#          [192, 198, 209],
#          [193, 199, 210],
#          ...,
#          [172, 184, 194],
#          [174, 188, 200],
#          [180, 194, 206]],
#
#         [[189, 195, 206],
#          [192, 198, 209],
#          [192, 198, 209],
#          ...,
#          [172, 185, 193],
#          [178, 190, 202],
#          [181, 195, 207]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\w.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-10'
#  semantic_mask: None
#  speed: {'preprocess': 0.8576000000175554, 'inference': 7.216300000436604, 'postprocess': 0.2469000000928645}]

# %%
# Evaluate the best checkpoint on the validation split
best = YOLO(r"C:\Users\ryano\Downloads\ntu\SC2079-GROUP31-ImageRec\Notebooks\Model Training Notebooks\runs\detect\runs_3(small_dataset)\train\weights\best.pt")
# best.val(data=DATA_YAML)

# Run detection on your test images and save the annotated results
# TEST_SOURCE = str(Path("Week8/test/images").resolve())  # <- point at your test folder
best.predict(source=r"C:\Users\ryano\Downloads\Telegram Desktop\New folder", conf=0.5, save=True)
# Out:
# image 1/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\2.jpg: 320x416 1 two, 6.9ms
# image 2/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\2b.jpg: 320x416 (no detections), 7.6ms
# image 3/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\2b2.jpg: 320x416 1 two, 8.7ms
# image 4/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\3b.jpg: 320x416 1 three, 6.8ms
# image 5/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\4b.jpg: 320x416 1 four, 7.1ms
# image 6/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\5.jpg: 320x416 1 five, 7.1ms
# image 7/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\7b.jpg: 320x416 1 seven, 7.2ms
# image 8/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\b.jpg: 320x416 1 B, 8.0ms
# image 9/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\bb.jpg: 320x416 (no detections), 7.6ms
# image 10/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\e.jpg: 320x416 1 E, 7.2ms
# image 11/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\f.jpg: 320x416 1 F, 6.4ms
# image 12/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\f2.jpg: 320x416 1 five, 7.6ms
# image 13/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\f3.jpg: 320x416 1 F, 7.0ms
# image 14/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\f4.jpg: 320x416 1 F, 7.1ms
# image 15/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\fb.jpg: 320x416 (no detections), 7.2ms
# image 16/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\h.jpg: 320x416 (no detections), 7.1ms
# image 17/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\imagerectest.jpg: 320x416 1 four, 9.4ms
# image 18/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\rectest.jpg: 320x416 1 four, 7.5ms
# image 19/19 C:\Users\ryano\Downloads\Telegram Desktop\New folder\w.jpg: 320x416 1 W, 6.4ms
# Speed: 1.0ms preprocess, 7.4ms inference, 0.4ms postprocess per image at shape (1, 3, 320, 416)
# Results saved to C:\Users\ryano\Downloads\ntu\SC2079-GROUP31-ImageRec\Notebooks\Model Training Notebooks\runs\detect\predict-9
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'A', 1: 'B', 2: 'Bullseye', 3: 'C', 4: 'D', 5: 'E', 6: 'F', 7: 'G', 8: 'H', 9: 'S', 10: 'T', 11: 'U', 12: 'V', 13: 'W', 14: 'X', 15: 'Y', 16: 'Z', 17: 'circle', 18: 'down', 19: 'eight', 20: 'five', 21: 'four', 22: 'left', 23: 'nine', 24: 'one', 25: 'right', 26: 'seven', 27: 'six', 28: 'three', 29: 'two', 30: 'up'}
#  obb: None
#  orig_img: array([[[124, 140, 122],
#          [127, 143, 126],
#          [125, 142, 128],
#          ...,
#          [144, 150, 155],
#          [146, 149, 157],
#          [153, 156, 164]],
#
#         [[124, 140, 123],
#          [124, 140, 123],
#          [128, 145, 131],
#          ...,
#          [144, 150, 155],
#          [145, 148, 156],
#          [150, 153, 161]],
#
#         [[122, 139, 125],
#          [121, 138, 124],
#          [125, 142, 129],
#          ...,
#          [145, 152, 155],
#          [148, 154, 159],
#          [147, 153, 158]],
#
#         ...,
#
#         [[157, 177, 178],
#          [156, 176, 177],
#          [158, 179, 177],
#          ...,
#          [102, 116, 122],
#          [ 96, 107, 111],
#          [ 96, 105, 108]],
#
#         [[158, 178, 179],
#          [157, 177, 178],
#          [164, 184, 185],
#          ...,
#          [ 99, 109, 116],
#          [ 98, 104, 109],
#          [ 96, 103, 106]],
#
#         [[159, 179, 180],
#          [164, 184, 185],
#          [169, 189, 190],
#          ...,
#          [101, 110, 114],
#          [ 99, 105, 110],
#          [100, 105, 108]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\2.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-9'
#  semantic_mask: None
#  speed: {'preprocess': 1.4512999996441067, 'inference': 6.893700000546232, 'postprocess': 0.36380000074132113},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'A', 1: 'B', 2: 'Bullseye', 3: 'C', 4: 'D', 5: 'E', 6: 'F', 7: 'G', 8: 'H', 9: 'S', 10: 'T', 11: 'U', 12: 'V', 13: 'W', 14: 'X', 15: 'Y', 16: 'Z', 17: 'circle', 18: 'down', 19: 'eight', 20: 'five', 21: 'four', 22: 'left', 23: 'nine', 24: 'one', 25: 'right', 26: 'seven', 27: 'six', 28: 'three', 29: 'two', 30: 'up'}
#  obb: None
#  orig_img: array([[[125, 145, 146],
#          [125, 145, 146],
#          [132, 148, 147],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[124, 142, 143],
#          [132, 150, 149],
#          [133, 149, 148],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[133, 149, 148],
#          [135, 152, 149],
#          [134, 151, 148],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[174, 173, 183],
#          [176, 175, 185],
#          [177, 178, 188],
#          ...,
#          [ 39,  49,  49],
#          [ 37,  47,  47],
#          [ 37,  47,  47]],
#
#         [[174, 172, 184],
#          [174, 172, 184],
#          [175, 174, 184],
#          ...,
#          [ 41,  54,  52],
#          [ 36,  50,  49],
#          [ 39,  53,  52]],
#
#         [[178, 176, 188],
#          [174, 172, 184],
#          [171, 170, 180],
#          ...,
#          [ 39,  53,  51],
#          [ 38,  54,  53],
#          [ 38,  54,  53]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\2b.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-9'
#  semantic_mask: None
#  speed: {'preprocess': 1.0673000006136135, 'inference': 7.590899999740941, 'postprocess': 0.2839999997377163},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'A', 1: 'B', 2: 'Bullseye', 3: 'C', 4: 'D', 5: 'E', 6: 'F', 7: 'G', 8: 'H', 9: 'S', 10: 'T', 11: 'U', 12: 'V', 13: 'W', 14: 'X', 15: 'Y', 16: 'Z', 17: 'circle', 18: 'down', 19: 'eight', 20: 'five', 21: 'four', 22: 'left', 23: 'nine', 24: 'one', 25: 'right', 26: 'seven', 27: 'six', 28: 'three', 29: 'two', 30: 'up'}
#  obb: None
#  orig_img: array([[[143, 151, 158],
#          [141, 149, 156],
#          [147, 158, 162],
#          ...,
#          [143, 157, 156],
#          [144, 161, 158],
#          [143, 160, 157]],
#
#         [[144, 152, 159],
#          [147, 155, 162],
#          [150, 159, 163],
#          ...,
#          [146, 160, 159],
#          [148, 162, 160],
#          [145, 162, 159]],
#
#         [[148, 154, 161],
#          [148, 156, 163],
#          [144, 152, 159],
#          ...,
#          [146, 159, 157],
#          [150, 162, 162],
#          [151, 165, 164]],
#
#         ...,
#
#         [[148, 167, 175],
#          [153, 172, 180],
#          [157, 175, 186],
#          ...,
#          [ 48,  40,  23],
#          [ 48,  41,  22],
#          [ 47,  41,  22]],
#
#         [[153, 169, 181],
#          [153, 169, 181],
#          [148, 166, 177],
#          ...,
#          [ 57,  49,  32],
#          [ 54,  47,  28],
#          [ 52,  45,  25]],
#
#         [[155, 169, 181],
#          [152, 168, 180],
#          [142, 158, 170],
#          ...,
#          [ 59,  49,  31],
#          [ 57,  50,  31],
#          [ 55,  48,  28]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\2b2.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-9'
#  semantic_mask: None
#  speed: {'preprocess': 0.9650000001784065, 'inference': 8.693900000253052, 'postprocess': 0.4361000001154025},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'A', 1: 'B', 2: 'Bullseye', 3: 'C', 4: 'D', 5: 'E', 6: 'F', 7: 'G', 8: 'H', 9: 'S', 10: 'T', 11: 'U', 12: 'V', 13: 'W', 14: 'X', 15: 'Y', 16: 'Z', 17: 'circle', 18: 'down', 19: 'eight', 20: 'five', 21: 'four', 22: 'left', 23: 'nine', 24: 'one', 25: 'right', 26: 'seven', 27: 'six', 28: 'three', 29: 'two', 30: 'up'}
#  obb: None
#  orig_img: array([[[134, 150, 149],
#          [136, 152, 151],
#          [128, 146, 145],
#          ...,
#          [147, 159, 159],
#          [145, 157, 159],
#          [142, 154, 156]],
#
#         [[132, 148, 147],
#          [132, 150, 149],
#          [128, 146, 145],
#          ...,
#          [144, 156, 156],
#          [145, 157, 159],
#          [145, 157, 159]],
#
#         [[130, 149, 146],
#          [129, 148, 145],
#          [128, 147, 144],
#          ...,
#          [142, 155, 157],
#          [144, 157, 159],
#          [145, 158, 160]],
#
#         ...,
#
#         [[171, 180, 193],
#          [174, 186, 198],
#          [173, 185, 195],
#          ...,
#          [ 66,  80,  86],
#          [ 68,  84,  91],
#          [ 66,  82,  89]],
#
#         [[172, 179, 194],
#          [169, 178, 191],
#          [175, 185, 195],
#          ...,
#          [ 64,  81,  84],
#          [ 67,  83,  89],
#          [ 67,  83,  89]],
#
#         [[172, 179, 194],
#          [172, 180, 193],
#          [171, 180, 193],
#          ...,
#          [ 64,  81,  84],
#          [ 65,  81,  87],
#          [ 66,  82,  88]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\3b.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-9'
#  semantic_mask: None
#  speed: {'preprocess': 0.9193999994749902, 'inference': 6.760300000678399, 'postprocess': 0.3231999999115942},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'A', 1: 'B', 2: 'Bullseye', 3: 'C', 4: 'D', 5: 'E', 6: 'F', 7: 'G', 8: 'H', 9: 'S', 10: 'T', 11: 'U', 12: 'V', 13: 'W', 14: 'X', 15: 'Y', 16: 'Z', 17: 'circle', 18: 'down', 19: 'eight', 20: 'five', 21: 'four', 22: 'left', 23: 'nine', 24: 'one', 25: 'right', 26: 'seven', 27: 'six', 28: 'three', 29: 'two', 30: 'up'}
#  obb: None
#  orig_img: array([[[152, 166, 165],
#          [150, 164, 163],
#          [145, 159, 158],
#          ...,
#          [144, 160, 167],
#          [141, 159, 166],
#          [140, 158, 165]],
#
#         [[155, 167, 167],
#          [148, 160, 160],
#          [145, 159, 158],
#          ...,
#          [147, 163, 169],
#          [141, 159, 166],
#          [141, 160, 165]],
#
#         [[149, 158, 161],
#          [149, 158, 161],
#          [153, 165, 167],
#          ...,
#          [146, 165, 168],
#          [144, 163, 168],
#          [145, 164, 167]],
#
#         ...,
#
#         [[151, 159, 172],
#          [146, 155, 165],
#          [147, 155, 168],
#          ...,
#          [ 83, 106, 108],
#          [ 84, 106, 111],
#          [ 84, 107, 109]],
#
#         [[153, 162, 176],
#          [153, 162, 175],
#          [146, 155, 169],
#          ...,
#          [ 85, 105, 110],
#          [ 87, 105, 112],
#          [ 86, 105, 110]],
#
#         [[147, 158, 172],
#          [151, 162, 176],
#          [149, 158, 172],
#          ...,
#          [ 87, 105, 112],
#          [ 90, 106, 113],
#          [ 90, 106, 113]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\4b.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-9'
#  semantic_mask: None
#  speed: {'preprocess': 0.7696000002397341, 'inference': 7.075199999235338, 'postprocess': 0.3872999996019644},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'A', 1: 'B', 2: 'Bullseye', 3: 'C', 4: 'D', 5: 'E', 6: 'F', 7: 'G', 8: 'H', 9: 'S', 10: 'T', 11: 'U', 12: 'V', 13: 'W', 14: 'X', 15: 'Y', 16: 'Z', 17: 'circle', 18: 'down', 19: 'eight', 20: 'five', 21: 'four', 22: 'left', 23: 'nine', 24: 'one', 25: 'right', 26: 'seven', 27: 'six', 28: 'three', 29: 'two', 30: 'up'}
#  obb: None
#  orig_img: array([[[133, 150, 141],
#          [130, 147, 138],
#          [133, 145, 139],
#          ...,
#          [146, 146, 158],
#          [140, 141, 151],
#          [139, 140, 150]],
#
#         [[134, 151, 142],
#          [134, 151, 142],
#          [131, 145, 139],
#          ...,
#          [143, 144, 154],
#          [140, 141, 151],
#          [139, 140, 150]],
#
#         [[130, 148, 141],
#          [132, 150, 143],
#          [123, 141, 134],
#          ...,
#          [135, 137, 147],
#          [137, 139, 149],
#          [140, 143, 151]],
#
#         ...,
#
#         [[176, 188, 194],
#          [178, 190, 196],
#          [174, 186, 190],
#          ...,
#          [195, 204, 208],
#          [195, 203, 210],
#          [195, 203, 210]],
#
#         [[176, 186, 193],
#          [175, 185, 192],
#          [177, 187, 194],
#          ...,
#          [197, 203, 208],
#          [195, 204, 208],
#          [195, 204, 208]],
#
#         [[176, 186, 193],
#          [176, 186, 193],
#          [176, 186, 193],
#          ...,
#          [197, 203, 208],
#          [195, 204, 208],
#          [195, 204, 208]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\5.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-9'
#  semantic_mask: None
#  speed: {'preprocess': 0.8756000006542308, 'inference': 7.119800000509713, 'postprocess': 0.3820000001724111},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'A', 1: 'B', 2: 'Bullseye', 3: 'C', 4: 'D', 5: 'E', 6: 'F', 7: 'G', 8: 'H', 9: 'S', 10: 'T', 11: 'U', 12: 'V', 13: 'W', 14: 'X', 15: 'Y', 16: 'Z', 17: 'circle', 18: 'down', 19: 'eight', 20: 'five', 21: 'four', 22: 'left', 23: 'nine', 24: 'one', 25: 'right', 26: 'seven', 27: 'six', 28: 'three', 29: 'two', 30: 'up'}
#  obb: None
#  orig_img: array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [126, 139, 141],
#          [136, 148, 150],
#          [134, 143, 146]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [131, 146, 148],
#          [133, 146, 148],
#          [134, 146, 148]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [128, 146, 147],
#          [133, 148, 150],
#          [136, 151, 153]],
#
#         ...,
#
#         [[ 33,  39,  44],
#          [ 34,  40,  45],
#          [ 41,  47,  54],
#          ...,
#          [ 38,  50,  60],
#          [ 35,  45,  55],
#          [ 36,  46,  56]],
#
#         [[ 31,  38,  41],
#          [ 36,  43,  46],
#          [ 43,  47,  52],
#          ...,
#          [ 38,  44,  57],
#          [ 40,  43,  57],
#          [ 37,  38,  52]],
#
#         [[ 29,  36,  39],
#          [ 35,  42,  45],
#          [ 42,  46,  51],
#          ...,
#          [ 43,  44,  58],
#          [ 39,  39,  53],
#          [ 41,  38,  53]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\7b.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-9'
#  semantic_mask: None
#  speed: {'preprocess': 1.1273000000073807, 'inference': 7.245900000270922, 'postprocess': 0.37400000019260915},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'A', 1: 'B', 2: 'Bullseye', 3: 'C', 4: 'D', 5: 'E', 6: 'F', 7: 'G', 8: 'H', 9: 'S', 10: 'T', 11: 'U', 12: 'V', 13: 'W', 14: 'X', 15: 'Y', 16: 'Z', 17: 'circle', 18: 'down', 19: 'eight', 20: 'five', 21: 'four', 22: 'left', 23: 'nine', 24: 'one', 25: 'right', 26: 'seven', 27: 'six', 28: 'three', 29: 'two', 30: 'up'}
#  obb: None
#  orig_img: array([[[123, 135, 135],
#          [127, 140, 138],
#          [132, 146, 144],
#          ...,
#          [135, 140, 141],
#          [132, 137, 140],
#          [130, 135, 138]],
#
#         [[123, 135, 135],
#          [130, 142, 142],
#          [136, 150, 148],
#          ...,
#          [135, 140, 141],
#          [132, 137, 140],
#          [133, 138, 141]],
#
#         [[130, 142, 142],
#          [131, 143, 143],
#          [133, 146, 144],
#          ...,
#          [133, 141, 141],
#          [138, 145, 148],
#          [140, 147, 150]],
#
#         ...,
#
#         [[176, 183, 192],
#          [174, 181, 190],
#          [177, 183, 190],
#          ...,
#          [155, 168, 176],
#          [150, 164, 170],
#          [154, 168, 174]],
#
#         [[181, 183, 193],
#          [180, 182, 192],
#          [185, 187, 195],
#          ...,
#          [155, 169, 175],
#          [156, 168, 174],
#          [157, 169, 175]],
#
#         [[178, 179, 189],
#          [183, 184, 194],
#          [188, 187, 196],
#          ...,
#          [155, 169, 175],
#          [157, 169, 175],
#          [158, 170, 176]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\b.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-9'
#  semantic_mask: None
#  speed: {'preprocess': 1.1492000003272551, 'inference': 7.989899999301997, 'postprocess': 0.37030000021331944},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'A', 1: 'B', 2: 'Bullseye', 3: 'C', 4: 'D', 5: 'E', 6: 'F', 7: 'G', 8: 'H', 9: 'S', 10: 'T', 11: 'U', 12: 'V', 13: 'W', 14: 'X', 15: 'Y', 16: 'Z', 17: 'circle', 18: 'down', 19: 'eight', 20: 'five', 21: 'four', 22: 'left', 23: 'nine', 24: 'one', 25: 'right', 26: 'seven', 27: 'six', 28: 'three', 29: 'two', 30: 'up'}
#  obb: None
#  orig_img: array([[[134, 145, 143],
#          [137, 150, 148],
#          [146, 158, 158],
#          ...,
#          [150, 156, 167],
#          [150, 151, 165],
#          [152, 151, 167]],
#
#         [[134, 145, 143],
#          [140, 151, 149],
#          [147, 159, 159],
#          ...,
#          [154, 160, 171],
#          [147, 150, 164],
#          [152, 153, 167]],
#
#         [[138, 149, 146],
#          [140, 151, 148],
#          [143, 154, 152],
#          ...,
#          [151, 160, 169],
#          [147, 153, 164],
#          [153, 157, 168]],
#
#         ...,
#
#         [[186, 193, 202],
#          [186, 193, 202],
#          [186, 191, 200],
#          ...,
#          [ 21,  19,  25],
#          [ 27,  25,  31],
#          [ 31,  29,  35]],
#
#         [[191, 196, 205],
#          [191, 196, 205],
#          [188, 193, 202],
#          ...,
#          [ 23,  18,  27],
#          [ 26,  22,  33],
#          [ 33,  29,  40]],
#
#         [[187, 192, 201],
#          [191, 196, 205],
#          [192, 197, 206],
#          ...,
#          [ 27,  22,  31],
#          [ 28,  24,  36],
#          [ 31,  27,  39]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\bb.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-9'
#  semantic_mask: None
#  speed: {'preprocess': 0.9468999996897765, 'inference': 7.625899999766261, 'postprocess': 0.3005999997185427},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'A', 1: 'B', 2: 'Bullseye', 3: 'C', 4: 'D', 5: 'E', 6: 'F', 7: 'G', 8: 'H', 9: 'S', 10: 'T', 11: 'U', 12: 'V', 13: 'W', 14: 'X', 15: 'Y', 16: 'Z', 17: 'circle', 18: 'down', 19: 'eight', 20: 'five', 21: 'four', 22: 'left', 23: 'nine', 24: 'one', 25: 'right', 26: 'seven', 27: 'six', 28: 'three', 29: 'two', 30: 'up'}
#  obb: None
#  orig_img: array([[[114, 122, 115],
#          [113, 121, 114],
#          [112, 119, 114],
#          ...,
#          [126, 138, 142],
#          [129, 140, 148],
#          [127, 140, 148]],
#
#         [[113, 121, 114],
#          [115, 123, 116],
#          [110, 121, 113],
#          ...,
#          [127, 139, 143],
#          [127, 141, 147],
#          [128, 142, 148]],
#
#         [[116, 127, 117],
#          [117, 128, 118],
#          [115, 129, 118],
#          ...,
#          [127, 140, 142],
#          [128, 143, 145],
#          [127, 144, 147]],
#
#         ...,
#
#         [[ 37,  58,  50],
#          [ 37,  55,  48],
#          [ 43,  59,  52],
#          ...,
#          [172, 188, 195],
#          [169, 182, 190],
#          [170, 184, 190]],
#
#         [[ 31,  61,  50],
#          [ 36,  63,  53],
#          [ 32,  57,  47],
#          ...,
#          [177, 189, 199],
#          [174, 187, 195],
#          [173, 186, 194]],
#
#         [[ 28,  62,  51],
#          [ 31,  63,  52],
#          [ 31,  61,  50],
#          ...,
#          [176, 188, 198],
#          [172, 184, 194],
#          [173, 186, 194]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\e.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-9'
#  semantic_mask: None
#  speed: {'preprocess': 0.8774999996603583, 'inference': 7.207099999504862, 'postprocess': 0.34729999970295466},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'A', 1: 'B', 2: 'Bullseye', 3: 'C', 4: 'D', 5: 'E', 6: 'F', 7: 'G', 8: 'H', 9: 'S', 10: 'T', 11: 'U', 12: 'V', 13: 'W', 14: 'X', 15: 'Y', 16: 'Z', 17: 'circle', 18: 'down', 19: 'eight', 20: 'five', 21: 'four', 22: 'left', 23: 'nine', 24: 'one', 25: 'right', 26: 'seven', 27: 'six', 28: 'three', 29: 'two', 30: 'up'}
#  obb: None
#  orig_img: array([[[ 52,  70,  53],
#          [ 54,  71,  57],
#          [ 53,  71,  58],
#          ...,
#          [124, 138, 137],
#          [133, 147, 145],
#          [137, 151, 149]],
#
#         [[ 55,  71,  54],
#          [ 55,  70,  56],
#          [ 55,  72,  59],
#          ...,
#          [129, 143, 142],
#          [134, 148, 146],
#          [138, 152, 150]],
#
#         [[ 60,  71,  55],
#          [ 57,  70,  56],
#          [ 56,  70,  58],
#          ...,
#          [131, 145, 144],
#          [135, 149, 148],
#          [137, 151, 150]],
#
#         ...,
#
#         [[101, 102,  98],
#          [ 98,  99,  95],
#          [ 98,  99,  95],
#          ...,
#          [ 60,  74,  72],
#          [ 67,  81,  77],
#          [ 69,  83,  79]],
#
#         [[ 96,  94,  93],
#          [ 94,  92,  91],
#          [ 99,  97,  96],
#          ...,
#          [ 65,  79,  77],
#          [ 69,  83,  81],
#          [ 73,  87,  85]],
#
#         [[ 98,  96,  96],
#          [ 97,  95,  95],
#          [100,  98,  97],
#          ...,
#          [ 67,  84,  81],
#          [ 73,  87,  85],
#          [ 73,  87,  85]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\f.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-9'
#  semantic_mask: None
#  speed: {'preprocess': 0.8663000007800292, 'inference': 6.362199999784934, 'postprocess': 0.32499999997526174},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'A', 1: 'B', 2: 'Bullseye', 3: 'C', 4: 'D', 5: 'E', 6: 'F', 7: 'G', 8: 'H', 9: 'S', 10: 'T', 11: 'U', 12: 'V', 13: 'W', 14: 'X', 15: 'Y', 16: 'Z', 17: 'circle', 18: 'down', 19: 'eight', 20: 'five', 21: 'four', 22: 'left', 23: 'nine', 24: 'one', 25: 'right', 26: 'seven', 27: 'six', 28: 'three', 29: 'two', 30: 'up'}
#  obb: None
#  orig_img: array([[[112, 141, 138],
#          [116, 143, 140],
#          [121, 143, 141],
#          ...,
#          [113, 123, 123],
#          [114, 127, 125],
#          [116, 129, 127]],
#
#         [[113, 140, 137],
#          [119, 143, 141],
#          [123, 144, 142],
#          ...,
#          [113, 125, 125],
#          [114, 126, 126],
#          [114, 127, 125]],
#
#         [[116, 139, 135],
#          [119, 140, 137],
#          [120, 139, 136],
#          ...,
#          [119, 131, 133],
#          [113, 125, 127],
#          [108, 122, 121]],
#
#         ...,
#
#         [[195, 207, 207],
#          [192, 204, 204],
#          [183, 195, 197],
#          ...,
#          [201, 209, 216],
#          [203, 211, 218],
#          [203, 211, 218]],
#
#         [[186, 199, 201],
#          [186, 199, 201],
#          [178, 191, 193],
#          ...,
#          [203, 212, 216],
#          [203, 211, 218],
#          [204, 212, 219]],
#
#         [[186, 201, 203],
#          [184, 199, 201],
#          [178, 191, 193],
#          ...,
#          [203, 212, 216],
#          [205, 213, 220],
#          [206, 214, 221]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\f2.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-9'
#  semantic_mask: None
#  speed: {'preprocess': 0.8288999997603241, 'inference': 7.599399999890011, 'postprocess': 0.4581000002872315},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'A', 1: 'B', 2: 'Bullseye', 3: 'C', 4: 'D', 5: 'E', 6: 'F', 7: 'G', 8: 'H', 9: 'S', 10: 'T', 11: 'U', 12: 'V', 13: 'W', 14: 'X', 15: 'Y', 16: 'Z', 17: 'circle', 18: 'down', 19: 'eight', 20: 'five', 21: 'four', 22: 'left', 23: 'nine', 24: 'one', 25: 'right', 26: 'seven', 27: 'six', 28: 'three', 29: 'two', 30: 'up'}
#  obb: None
#  orig_img: array([[[ 48,  38,  38],
#          [ 43,  35,  35],
#          [ 45,  37,  38],
#          ...,
#          [198, 197, 207],
#          [203, 199, 211],
#          [205, 201, 213]],
#
#         [[ 50,  40,  40],
#          [ 46,  38,  38],
#          [ 43,  37,  38],
#          ...,
#          [199, 198, 208],
#          [203, 199, 211],
#          [205, 201, 213]],
#
#         [[ 52,  44,  45],
#          [ 50,  44,  45],
#          [ 42,  40,  40],
#          ...,
#          [198, 197, 206],
#          [204, 200, 211],
#          [208, 204, 215]],
#
#         ...,
#
#         [[221, 236, 239],
#          [219, 234, 237],
#          [221, 233, 237],
#          ...,
#          [ 60,  79,  82],
#          [ 64,  81,  84],
#          [ 66,  83,  86]],
#
#         [[218, 232, 238],
#          [217, 231, 237],
#          [220, 232, 238],
#          ...,
#          [ 62,  82,  83],
#          [ 59,  79,  80],
#          [ 62,  82,  83]],
#
#         [[216, 230, 236],
#          [218, 232, 238],
#          [221, 233, 239],
#          ...,
#          [ 62,  83,  81],
#          [ 55,  76,  74],
#          [ 59,  80,  78]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\f3.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-9'
#  semantic_mask: None
#  speed: {'preprocess': 0.9404000002177781, 'inference': 6.972800000767165, 'postprocess': 0.3612000000430271},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'A', 1: 'B', 2: 'Bullseye', 3: 'C', 4: 'D', 5: 'E', 6: 'F', 7: 'G', 8: 'H', 9: 'S', 10: 'T', 11: 'U', 12: 'V', 13: 'W', 14: 'X', 15: 'Y', 16: 'Z', 17: 'circle', 18: 'down', 19: 'eight', 20: 'five', 21: 'four', 22: 'left', 23: 'nine', 24: 'one', 25: 'right', 26: 'seven', 27: 'six', 28: 'three', 29: 'two', 30: 'up'}
#  obb: None
#  orig_img: array([[[ 65,  59,  60],
#          [ 64,  58,  59],
#          [ 70,  59,  62],
#          ...,
#          [143, 152, 155],
#          [147, 156, 159],
#          [146, 155, 158]],
#
#         [[ 65,  59,  60],
#          [ 66,  60,  61],
#          [ 70,  61,  64],
#          ...,
#          [143, 152, 155],
#          [146, 155, 158],
#          [146, 155, 158]],
#
#         [[ 70,  65,  66],
#          [ 74,  68,  69],
#          [ 70,  64,  65],
#          ...,
#          [142, 151, 154],
#          [142, 151, 154],
#          [145, 154, 157]],
#
#         ...,
#
#         [[167, 176, 190],
#          [170, 179, 193],
#          [170, 179, 192],
#          ...,
#          [201, 207, 212],
#          [204, 210, 215],
#          [206, 212, 217]],
#
#         [[163, 175, 187],
#          [164, 176, 188],
#          [166, 178, 190],
#          ...,
#          [201, 210, 214],
#          [205, 211, 216],
#          [206, 212, 217]],
#
#         [[160, 172, 184],
#          [162, 174, 186],
#          [161, 173, 185],
#          ...,
#          [201, 210, 214],
#          [205, 211, 216],
#          [205, 211, 216]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\f4.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-9'
#  semantic_mask: None
#  speed: {'preprocess': 0.9053000003405032, 'inference': 7.128100000045379, 'postprocess': 0.36439999985304894},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'A', 1: 'B', 2: 'Bullseye', 3: 'C', 4: 'D', 5: 'E', 6: 'F', 7: 'G', 8: 'H', 9: 'S', 10: 'T', 11: 'U', 12: 'V', 13: 'W', 14: 'X', 15: 'Y', 16: 'Z', 17: 'circle', 18: 'down', 19: 'eight', 20: 'five', 21: 'four', 22: 'left', 23: 'nine', 24: 'one', 25: 'right', 26: 'seven', 27: 'six', 28: 'three', 29: 'two', 30: 'up'}
#  obb: None
#  orig_img: array([[[123, 144, 136],
#          [126, 147, 139],
#          [120, 141, 133],
#          ...,
#          [136, 156, 157],
#          [136, 156, 157],
#          [128, 148, 149]],
#
#         [[123, 143, 138],
#          [122, 143, 135],
#          [120, 141, 133],
#          ...,
#          [136, 156, 157],
#          [135, 155, 156],
#          [134, 154, 155]],
#
#         [[118, 137, 134],
#          [118, 138, 133],
#          [119, 136, 132],
#          ...,
#          [134, 154, 155],
#          [135, 154, 157],
#          [143, 162, 165]],
#
#         ...,
#
#         [[237, 248, 246],
#          [239, 250, 248],
#          [241, 252, 250],
#          ...,
#          [ 74,  86,  88],
#          [ 96, 108, 112],
#          [ 97, 111, 117]],
#
#         [[242, 255, 253],
#          [242, 255, 253],
#          [243, 255, 253],
#          ...,
#          [ 73,  85,  87],
#          [ 91, 103, 109],
#          [ 97, 110, 118]],
#
#         [[241, 255, 253],
#          [242, 255, 254],
#          [242, 255, 252],
#          ...,
#          [ 74,  86,  88],
#          [ 88, 100, 106],
#          [ 98, 111, 119]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\fb.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-9'
#  semantic_mask: None
#  speed: {'preprocess': 1.0464999995747348, 'inference': 7.159699999647273, 'postprocess': 0.37040000006527407},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'A', 1: 'B', 2: 'Bullseye', 3: 'C', 4: 'D', 5: 'E', 6: 'F', 7: 'G', 8: 'H', 9: 'S', 10: 'T', 11: 'U', 12: 'V', 13: 'W', 14: 'X', 15: 'Y', 16: 'Z', 17: 'circle', 18: 'down', 19: 'eight', 20: 'five', 21: 'four', 22: 'left', 23: 'nine', 24: 'one', 25: 'right', 26: 'seven', 27: 'six', 28: 'three', 29: 'two', 30: 'up'}
#  obb: None
#  orig_img: array([[[ 40,  49,  52],
#          [ 43,  52,  55],
#          [ 41,  51,  51],
#          ...,
#          [146, 154, 144],
#          [147, 155, 144],
#          [149, 157, 146]],
#
#         [[ 38,  47,  50],
#          [ 41,  50,  53],
#          [ 42,  51,  54],
#          ...,
#          [147, 155, 145],
#          [146, 154, 144],
#          [146, 155, 145]],
#
#         [[ 44,  50,  55],
#          [ 45,  51,  56],
#          [ 42,  48,  53],
#          ...,
#          [145, 152, 145],
#          [143, 151, 144],
#          [139, 150, 142]],
#
#         ...,
#
#         [[171, 181, 191],
#          [169, 179, 189],
#          [169, 179, 189],
#          ...,
#          [ 11,  12,  10],
#          [ 11,  12,  10],
#          [  9,  10,   8]],
#
#         [[171, 180, 189],
#          [171, 180, 189],
#          [170, 181, 189],
#          ...,
#          [ 13,  12,   8],
#          [ 12,  10,   9],
#          [  9,   7,   6]],
#
#         [[172, 181, 190],
#          [172, 181, 190],
#          [169, 180, 188],
#          ...,
#          [ 11,  10,   6],
#          [  9,   7,   6],
#          [ 10,   8,   7]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\h.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-9'
#  semantic_mask: None
#  speed: {'preprocess': 0.9741000003486988, 'inference': 7.082200000695593, 'postprocess': 0.24880000000848668},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'A', 1: 'B', 2: 'Bullseye', 3: 'C', 4: 'D', 5: 'E', 6: 'F', 7: 'G', 8: 'H', 9: 'S', 10: 'T', 11: 'U', 12: 'V', 13: 'W', 14: 'X', 15: 'Y', 16: 'Z', 17: 'circle', 18: 'down', 19: 'eight', 20: 'five', 21: 'four', 22: 'left', 23: 'nine', 24: 'one', 25: 'right', 26: 'seven', 27: 'six', 28: 'three', 29: 'two', 30: 'up'}
#  obb: None
#  orig_img: array([[[125, 132, 135],
#          [123, 130, 133],
#          [124, 133, 137],
#          ...,
#          [156, 158, 168],
#          [157, 159, 169],
#          [161, 163, 173]],
#
#         [[124, 131, 134],
#          [130, 137, 140],
#          [127, 136, 140],
#          ...,
#          [156, 158, 168],
#          [157, 159, 169],
#          [158, 160, 170]],
#
#         [[130, 138, 138],
#          [130, 138, 138],
#          [123, 132, 135],
#          ...,
#          [156, 159, 167],
#          [156, 162, 169],
#          [156, 162, 169]],
#
#         ...,
#
#         [[198, 206, 213],
#          [201, 209, 216],
#          [202, 210, 217],
#          ...,
#          [175, 192, 195],
#          [178, 193, 196],
#          [175, 192, 195]],
#
#         [[192, 203, 207],
#          [192, 203, 207],
#          [199, 208, 212],
#          ...,
#          [168, 187, 190],
#          [172, 189, 192],
#          [174, 193, 196]],
#
#         [[189, 200, 204],
#          [191, 202, 206],
#          [197, 206, 210],
#          ...,
#          [169, 188, 191],
#          [168, 187, 190],
#          [174, 193, 196]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\imagerectest.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-9'
#  semantic_mask: None
#  speed: {'preprocess': 0.8992999992187833, 'inference': 9.427400000276975, 'postprocess': 0.44999999954598024},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'A', 1: 'B', 2: 'Bullseye', 3: 'C', 4: 'D', 5: 'E', 6: 'F', 7: 'G', 8: 'H', 9: 'S', 10: 'T', 11: 'U', 12: 'V', 13: 'W', 14: 'X', 15: 'Y', 16: 'Z', 17: 'circle', 18: 'down', 19: 'eight', 20: 'five', 21: 'four', 22: 'left', 23: 'nine', 24: 'one', 25: 'right', 26: 'seven', 27: 'six', 28: 'three', 29: 'two', 30: 'up'}
#  obb: None
#  orig_img: array([[[ 79,  89,  83],
#          [ 80,  90,  84],
#          [ 80,  90,  84],
#          ...,
#          [142, 153, 150],
#          [146, 157, 155],
#          [142, 153, 151]],
#
#         [[ 79,  86,  81],
#          [ 80,  90,  84],
#          [ 82,  89,  84],
#          ...,
#          [146, 159, 157],
#          [148, 159, 157],
#          [145, 158, 156]],
#
#         [[ 83,  90,  83],
#          [ 79,  87,  80],
#          [ 77,  83,  78],
#          ...,
#          [151, 165, 163],
#          [147, 160, 158],
#          [144, 158, 156]],
#
#         ...,
#
#         [[ 73,  73,  89],
#          [ 81,  84,  98],
#          [ 80,  85,  94],
#          ...,
#          [ 57,  76,  79],
#          [ 62,  81,  84],
#          [ 60,  81,  82]],
#
#         [[ 74,  73,  89],
#          [ 73,  73,  87],
#          [ 79,  81,  91],
#          ...,
#          [ 52,  73,  75],
#          [ 54,  75,  77],
#          [ 54,  77,  79]],
#
#         [[ 73,  70,  86],
#          [ 73,  73,  87],
#          [ 74,  75,  85],
#          ...,
#          [ 50,  71,  73],
#          [ 46,  69,  71],
#          [ 50,  73,  75]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\rectest.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-9'
#  semantic_mask: None
#  speed: {'preprocess': 0.8401999994021025, 'inference': 7.492499999898428, 'postprocess': 0.31969999963621376},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  depth: None
#  keypoints: None
#  masks: None
#  names: {0: 'A', 1: 'B', 2: 'Bullseye', 3: 'C', 4: 'D', 5: 'E', 6: 'F', 7: 'G', 8: 'H', 9: 'S', 10: 'T', 11: 'U', 12: 'V', 13: 'W', 14: 'X', 15: 'Y', 16: 'Z', 17: 'circle', 18: 'down', 19: 'eight', 20: 'five', 21: 'four', 22: 'left', 23: 'nine', 24: 'one', 25: 'right', 26: 'seven', 27: 'six', 28: 'three', 29: 'two', 30: 'up'}
#  obb: None
#  orig_img: array([[[130, 160, 155],
#          [137, 164, 160],
#          [137, 163, 157],
#          ...,
#          [ 83,  87,  82],
#          [ 79,  83,  77],
#          [ 79,  83,  77]],
#
#         [[133, 158, 154],
#          [133, 158, 154],
#          [139, 162, 158],
#          ...,
#          [ 80,  84,  79],
#          [ 77,  81,  76],
#          [ 78,  82,  77]],
#
#         [[144, 162, 161],
#          [143, 162, 159],
#          [144, 161, 158],
#          ...,
#          [ 80,  82,  82],
#          [ 82,  82,  82],
#          [ 78,  79,  77]],
#
#         ...,
#
#         [[187, 193, 206],
#          [189, 195, 208],
#          [194, 200, 211],
#          ...,
#          [169, 183, 195],
#          [171, 185, 197],
#          [174, 190, 203]],
#
#         [[190, 196, 207],
#          [192, 198, 209],
#          [193, 199, 210],
#          ...,
#          [172, 184, 194],
#          [174, 188, 200],
#          [180, 194, 206]],
#
#         [[189, 195, 206],
#          [192, 198, 209],
#          [192, 198, 209],
#          ...,
#          [172, 185, 193],
#          [178, 190, 202],
#          [181, 195, 207]]], shape=(2464, 3280, 3), dtype=uint8)
#  orig_shape: (2464, 3280)
#  path: 'C:\\Users\\ryano\\Downloads\\Telegram Desktop\\New folder\\w.jpg'
#  probs: None
#  save_dir: 'C:\\Users\\ryano\\Downloads\\ntu\\SC2079-GROUP31-ImageRec\\Notebooks\\Model Training Notebooks\\runs\\detect\\predict-9'
#  semantic_mask: None
#  speed: {'preprocess': 0.7630000000062864, 'inference': 6.4265000000887085, 'postprocess': 0.3464999999778229}]

# %% [markdown]
# # Step 6: Deploy to the Inference Server
#
# Copies `best.pt` into the inference server directory as the checkpoint that `load_model()` in `model.py` expects. The model.py path is `YOLO26_Week_9.pt` (Task 2 / left-right-bullseye); for Task 1 use `YOLO26_Week_8.pt` and update the path in `model.py`.

# %%
import shutil
from pathlib import Path

# The inference server folder is 2 levels up from this notebook
server_dir = Path.cwd().resolve().parents[1] / "YOLOv5 Inference Server"
dest = server_dir / "YOLO26_Week_9.pt"   # use YOLO26_Week_8.pt for Task 1
shutil.copy(f"{PROJECT}/train/weights/best.pt", dest)
print("Copied best.pt to", dest)

# %% [markdown]
# ## Notes
#
# - **Offline caveat**: `yolo26s.pt` is fetched once over the network on first run (it is cached next to your script/notebook). Everything after that - training, validation, inference - is fully local.
# - Runs are saved under `runs/` next to this notebook. Delete old `runs/train/*` folders or change `name=` to avoid collisions.
# - The vendored YOLOv5 files in the inference server folder are unused legacy code; training here only needs the `ultralytics` package.
